# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandouribeu/analisis_datos/blob/main/lab01_ad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# En la seccion anterior se importo pandas y numpy

# %%
df = pd.read_csv("clientes_retail.csv")

# %% [markdown]
# Se importo el csv como data frame

# %%
df.head()
# Out:
#   customer_id  age     gender      education marital_status  income_clp  \
# 0      C00001   47   Femenino          Media        Soltero    781889.0
# 1      C00002   40   Femenino          Media        Soltero   1242577.0
# 2      C00003   49  Masculino          Media        Soltero   1347579.0
# 3      C00004   60  Masculino        Técnica         Casado    686279.0
# 4      C00005   39   Femenino  Universitaria         Casado   1394730.0
#
#       region registration_date  total_purchases  total_spent_clp  \
# 0     Biobío        2024-02-05               12           537694
# 1  Araucanía        2020-02-11                9           862822
# 2  Araucanía        2020-10-12               20          1195473
# 3     Biobío        2023-10-13               15          1571007
# 4     Biobío        2018-01-29               14           410407
#
#    online_purchases  store_purchases  complaints  satisfaction_score  \
# ...

# %%
df.shape
# Out:
# (1020, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         1020 non-null   object
#  1   age                 1020 non-null   int64
#  2   gender              1020 non-null   object
#  3   education           969 non-null    object
#  4   marital_status      1020 non-null   object
#  5   income_clp          916 non-null    float64
#  6   region              1020 non-null   object
#  7   registration_date   1020 non-null   object
#  8   total_purchases     1020 non-null   int64
#  9   total_spent_clp     1020 non-null   int64
#  10  online_purchases    1020 non-null   int64
#  11  store_purchases     1020 non-null   int64
#  12  complaints          1020 non-null   int64
#  13  satisfaction_score  990 non-null    float64
#  14  last_purchase_days  1020 non-null   int64
# dtypes: float64(2), int64(7), object(6)
# ...

# %%
df.describe()
# Out:
#                age    income_clp  total_purchases  total_spent_clp  \
# count  1020.000000  9.160000e+02      1020.000000     1.020000e+03
# mean     42.037255  1.344718e+06        15.137255     1.065511e+06
# std      12.772355  1.009656e+06         3.782713     2.264178e+06
# min       5.000000 -5.000000e+05         3.000000    -3.000000e+04
# 25%      34.000000  8.591062e+05        12.000000     5.354258e+05
# 50%      42.000000  1.200099e+06        15.000000     8.158990e+05
# 75%      49.000000  1.618652e+06        18.000000     1.223987e+06
# max     150.000000  2.500000e+07        27.000000     5.000000e+07
#
#        online_purchases  store_purchases   complaints  satisfaction_score  \
# count       1020.000000      1020.000000  1020.000000          990.000000
# mean           7.025490         8.058824     1.103922            3.665657
# std            2.691414         2.815991     1.852507            1.081292
# ...

# %%
df.isnull().sum()
# Out:
# customer_id             0
# age                     0
# gender                  0
# education              51
# marital_status          0
# income_clp            104
# region                  0
# registration_date       0
# total_purchases         0
# total_spent_clp         0
# online_purchases        0
# store_purchases         0
# complaints              0
# satisfaction_score     30
# last_purchase_days      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(20)
